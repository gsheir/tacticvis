# %% [markdown]
# # Seeing what competitions are available

# %%
from statsbombpy import sb
from utils.statsbomb_wrappers import search_in_dataframe
import warnings

warnings.simplefilter("ignore")

# %%
sb.competitions()
# Out:
#     competition_id  season_id   country_name    competition_name  \
# 0                9         27        Germany       1. Bundesliga
# 1               16          4         Europe    Champions League
# 2               16          1         Europe    Champions League
# 3               16          2         Europe    Champions League
# 4               16         27         Europe    Champions League
# ..             ...        ...            ...                 ...
# 65              55         43         Europe           UEFA Euro
# 66              35         75         Europe  UEFA Europa League
# 67              53        106         Europe   UEFA Women's Euro
# 68              72        107  International   Women's World Cup
# 69              72         30  International   Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# ...

# %%
events = sb.events(match_id=3847567)

# %%
search_in_dataframe(events, type="Shot")
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 3507   NaN                NaN                  NaN                     NaN
# 3508   NaN                NaN                  NaN                     NaN
# 3509   NaN                NaN                  NaN                     NaN
# 3510   NaN                NaN                  NaN                     NaN
# 3511   NaN                NaN                  NaN                     NaN
# 3512   NaN                NaN                  NaN                     NaN
# 3513   NaN                NaN                  NaN                     NaN
# 3514   NaN                NaN                  NaN                     NaN
# 3515   NaN                NaN                  NaN                     NaN
# 3516   NaN                NaN                  NaN                     NaN
# 3517   NaN                NaN                  NaN                     NaN
# ...

# %% [markdown]
# # Pitch locations

# %%
from utils.statsbomb_wrappers import PitchDim

# %%
PitchDim.DEF_GOAL_LPOST
# Out:
# <PitchDim.DEF_GOAL_LPOST: (0, 36.0)>
